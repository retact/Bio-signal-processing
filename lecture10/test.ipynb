# %% [markdown]
# <a href="https://colab.research.google.com/github/retact/Bio-signal-processing/blob/main/lecture10/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Biological_signal/
# Out:
# /content/drive/My Drive/Biological_signal

# %%
# !git clone https://github.com/retact/Bio-signal-processing.git
# Out:
# /content/drive/My Drive/Biological_signal
# Cloning into 'Bio-signal-processing'...
# remote: Enumerating objects: 182, done.
# remote: Counting objects: 100% (182/182), done.
# remote: Compressing objects: 100% (135/135), done.
# remote: Total 182 (delta 64), reused 126 (delta 40), pack-reused 0
# Receiving objects: 100% (182/182), 41.45 MiB | 14.86 MiB/s, done.
# Resolving deltas: 100% (64/64), done.
# Checking out files: 100% (77/77), done.

# %%
# %matplotlib inline
import cv2
from skimage.io import imread
import matplotlib.pylab as plt
img = cv2.imread("/content/drive/MyDrive/Biological_signal/Bio-signal-processing/lecture9/sample_image/IMG_6205.png")

# %%
# %cd Bio-signal-processing/
# %mkdir lecture10 
# %cd lecture10
# Out:
# /content/drive/My Drive/Biological_signal/Bio-signal-processing
# mkdir: cannot create directory ‘lecture10’: File exists
# /content/drive/My Drive/Biological_signal/Bio-signal-processing/lecture10

# %%
cv2.imwrite('./output.jpg',img)
# %ls
# Out:
# output.jpg  src/

# %%
# gray scale
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray,cmap='gray')

# %%
img_read_gray = cv2.imread("./src/Berry.jpg", 0)
plt.imshow(img_read_gray,cmap='gray')

# %%
img_orig= cv2.imread("./src/grapes.jpg")
img_gray= cv2.cvtColor(img_orig, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(12, 3))
plt.subplot(1, 2, 1)
plt.title('input')
plt.imshow(cv2.cvtColor(img_orig, cv2.COLOR_BGR2RGB))
plt.subplot(1, 2, 2)
plt.title('grayscale image')
plt.imshow(img_gray, cmap='gray')
plt.show()

# %%
hsv= cv2.cvtColor(img_orig, cv2.COLOR_BGR2HSV) 
# BGR -> HSV
hsv[..., 1] = 100
img_hsv= cv2.cvtColor(hsv, cv2.COLOR_HSV2RGB) # HSV -> RGB


# 2値化の閾値
threshold = 100
# 画像を2値化
ret, img_th= cv2.threshold(img_gray, threshold, 255, cv2.THRESH_BINARY)
plt.imshow(img_th, cmap= "gray")

# %%
# hist
hist = cv2.calcHist([img_gray], [0], None, [256], [0, 256])
plt.plot(hist)
plt.xlabel("pixel value")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
ret, img_otsu= cv2.threshold(img_gray, 0, 255, cv2.THRESH_OTSU)
plt.imshow(img_otsu, cmap= "gray")
